# %%
import inspect_event as ie
from importlib import reload

# %% [markdown]
# Plot a graph in 3d, where the colour is determined by time and the size of the point is determined by charge.
#
# Generally, the only thing you need to do is modify the file path to the db_file in load_event.
#
# Inspect takes an integer (as just event number x in the database), if not given a specific event_no.
#
# Angle specifies the initial angle (azimuthal) to see the plot from. If you plot with matplotlib notebook you can control the angle.
#
# if Degree, we colour based on node degree and not ti,e
#
# if hist, distributions of node features are shown.
#
# save should be self-explanatory.

# %%
# %matplotlib notebook
reload(ie)
inspect=ie.inspect
inspect(2100, event_no=12971854, n_neighbors=8, hist=False, muon=False, db_path='../db_files/dev_lvl7/dev_lvl7_mu_nu_e_classification_v003.db',
       transform_path='../db_files/dev_lvl7/transformers.pkl', )
# Out:
# Removed and ready to reload
# Connecting to db-file
# Reading files
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such column: time
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-6f06acc353e9> in <module>
#       2 reload(ie)
#       3 inspect=ie.inspect
# ----> 4 inspect(2100, event_no=12971854, n_neighbors=8, hist=False, muon=False, db_path='../db_files/dev_lvl7/dev_lvl7_mu_nu_e_classification_v003.db',
#       5        transform_path='../db_files/dev_lvl7/transformers.pkl', )
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in inspect(event, muon, event_no, n_neighbors, angle, save, degree, hist, transform_path, db_path)
#      35         hist: if true distributions of node features are shown.
#      36         save should be self-explanatory.'''
# ---> 37     dt=load_event(event, event_no, db_path=db_path, n_neighbors=n_neighbors, transform_path=transform_path, muon=muon)[0]
#      38     X, A, Y=dt.x, dt.a, dt.y
#      39     if hist:
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in __init__(self, event, event_no, transform, muon, n_neighbors, transform_path, db_path, restart, **kwargs)
#     131         self.k=0
#     132         self.db_path=db_path
# --> 133         super().__init__(**kwargs)
#     134
#     135     @property
#
# ~\AppData\Roaming\Python\Python38\site-packages\spektral\data\dataset.py in __init__(self, transforms, **kwargs)
#      96
#      97         # Read graphs
# ---> 98         self.graphs = self.read()
#      99         if len(self.graphs) == 0:
#     100             raise ValueError('Datasets cannot be empty')
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in read(self)
#     225         if self.restart and self.k==0:
#     226             self.reload()
# --> 227             self.download()
#     228             self.k+=1
#     229         print("Loading data to memory")
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in download(self)
#     185                 print("Reading files")
#     186                 df_event = read_sql(f"select event_no       from features where event_no == {self.event_no}", conn)
# --> 187                 df_feat  = read_sql(f"select {feature_call} from features where event_no == {self.event_no}", conn)
#     188                 df_targ  = read_sql(f"select {target_call } from truth    where event_no == {self.event_no}", conn)
#     189
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'select dom_x, dom_y, dom_z, time, charge_log10 from features where event_no == 12971854': no such column: time

# %%
# %matplotlib notebook
reload(ie)
inspect=ie.inspect
inspect(2100, event_no=117102188, n_neighbors=6, hist=False, muon=False, db_path='../db_files/dev_lvl7/dev_lvl7_mu_nu_e_classification_v003.db',
       transform_path='../db_files/dev_lvl7/transformers.pkl', )
# Out:
# Removed and ready to reload
# Connecting to db-file
# Reading files
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such column: time
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-7b3e9634eb92> in <module>
#       2 reload(ie)
#       3 inspect=ie.inspect
# ----> 4 inspect(2100, event_no=117102188, n_neighbors=6, hist=False, muon=False, db_path='../db_files/dev_lvl7/dev_lvl7_mu_nu_e_classification_v003.db',
#       5        transform_path='../db_files/dev_lvl7/transformers.pkl', )
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in inspect(event, muon, event_no, n_neighbors, angle, save, degree, hist, transform_path, db_path)
#      35         hist: if true distributions of node features are shown.
#      36         save should be self-explanatory.'''
# ---> 37     dt=load_event(event, event_no, db_path=db_path, n_neighbors=n_neighbors, transform_path=transform_path, muon=muon)[0]
#      38     X, A, Y=dt.x, dt.a, dt.y
#      39     if hist:
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in __init__(self, event, event_no, transform, muon, n_neighbors, transform_path, db_path, restart, **kwargs)
#     131         self.k=0
#     132         self.db_path=db_path
# --> 133         super().__init__(**kwargs)
#     134
#     135     @property
#
# ~\AppData\Roaming\Python\Python38\site-packages\spektral\data\dataset.py in __init__(self, transforms, **kwargs)
#      96
#      97         # Read graphs
# ---> 98         self.graphs = self.read()
#      99         if len(self.graphs) == 0:
#     100             raise ValueError('Datasets cannot be empty')
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in read(self)
#     225         if self.restart and self.k==0:
#     226             self.reload()
# --> 227             self.download()
#     228             self.k+=1
#     229         print("Loading data to memory")
#
# ~\Christian\3YR-UNI\Bachelor\IceCube\inspect\inspect_event.py in download(self)
#     185                 print("Reading files")
#     186                 df_event = read_sql(f"select event_no       from features where event_no == {self.event_no}", conn)
# --> 187                 df_feat  = read_sql(f"select {feature_call} from features where event_no == {self.event_no}", conn)
#     188                 df_targ  = read_sql(f"select {target_call } from truth    where event_no == {self.event_no}", conn)
#     189
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'select dom_x, dom_y, dom_z, time, charge_log10 from features where event_no == 117102188': no such column: time

# %%
# %matplotlib inline
reload(ie)
inspect(1., event_no=138674361, hist=False, muon=1, angle=230, n_neighbors=6)
# Out:
# Removed and ready to reload
# Connecting to db-file
# Reading files
# Generating adjacency matrices
# Saving dataset
# Loading data to memory
