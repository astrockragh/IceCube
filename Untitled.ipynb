# %%
from inspect_event import inspect

# %%
# %matplotlib inline
inspect(10000)
# Out:
# Removed and ready to reload
# Connecting to db-file
# Loading Muons
# Reading files
# Generating adjacency matrices
# Saving dataset
# Loading data to memory
